# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'd:\\ESCOM\\PCD\\PrograCienciasDeDatos\\ProyectoProgra'

# %%
dating = pd.read_csv('c:\\Users\\emlom\\OneDrive\\Documents\\3semestre\\PrograCienciasDeDatos\\ProyectoProgra\\Speed Dating Data(editado).csv')
dating
# Out:
#       iid  gender    pid  match   age  race  imprace  imprelig     from  \
# 0       1       0   11.0      0  21.0   4.0      2.0       4.0  Chicago
# 1       1       0   12.0      0  21.0   4.0      2.0       4.0  Chicago
# 2       1       0   13.0      1  21.0   4.0      2.0       4.0  Chicago
# 3       1       0   14.0      1  21.0   4.0      2.0       4.0  Chicago
# 4       1       0   15.0      1  21.0   4.0      2.0       4.0  Chicago
# ...   ...     ...    ...    ...   ...   ...      ...       ...      ...
# 8373  552       1  526.0      0  25.0   2.0      1.0       1.0   France
# 8374  552       1  527.0      0  25.0   2.0      1.0       1.0   France
# 8375  552       1  528.0      0  25.0   2.0      1.0       1.0   France
# 8376  552       1  529.0      0  25.0   2.0      1.0       1.0   France
# 8377  552       1  530.0      0  25.0   2.0      1.0       1.0   France
#
#          income  ...  Ambitious  Shared Interests/Hobbies like  prob  \
# ...

# %%
dating_frame = pd.DataFrame(dating)
dating_frame
# Out:
#       iid  gender    pid  match   age  race  imprace  imprelig     from  \
# 0       1       0   11.0      0  21.0   4.0      2.0       4.0  Chicago
# 1       1       0   12.0      0  21.0   4.0      2.0       4.0  Chicago
# 2       1       0   13.0      1  21.0   4.0      2.0       4.0  Chicago
# 3       1       0   14.0      1  21.0   4.0      2.0       4.0  Chicago
# 4       1       0   15.0      1  21.0   4.0      2.0       4.0  Chicago
# ...   ...     ...    ...    ...   ...   ...      ...       ...      ...
# 8373  552       1  526.0      0  25.0   2.0      1.0       1.0   France
# 8374  552       1  527.0      0  25.0   2.0      1.0       1.0   France
# 8375  552       1  528.0      0  25.0   2.0      1.0       1.0   France
# 8376  552       1  529.0      0  25.0   2.0      1.0       1.0   France
# 8377  552       1  530.0      0  25.0   2.0      1.0       1.0   France
#
#          income  ...  Ambitious  Shared Interests/Hobbies like  prob  \
# ...

# %%
id_match = dating_frame[['pid','match']]
id_match
# Out:
#         pid  match
# 0      11.0      0
# 1      12.0      0
# 2      13.0      1
# 3      14.0      1
# 4      15.0      1
# ...     ...    ...
# 8373  526.0      0
# 8374  527.0      0
# 8375  528.0      0
# 8376  529.0      0
# 8377  530.0      0
#
# [8378 rows x 2 columns]

# %%
group_idmatch = id_match.groupby(['pid','match']).size().unstack(fill_value=1)
group_idmatch.columns = ['no','yes']
group_idmatch
# Out:
#        no  yes
# pid
# 1.0     6    4
# 2.0     8    2
# 3.0    10    1
# 4.0     8    2
# 5.0     8    2
# ...    ..  ...
# 548.0  17    5
# 549.0  17    5
# 550.0  18    4
# 551.0  20    2
# 552.0  16    6
#
# [551 rows x 2 columns]

# %%
group_idmatch.to_excel('c:\\Users\\emlom\\OneDrive\\Documents\\3semestre\\PrograCienciasDeDatos\\ProyectoProgra\\group_idmatch.xlsx', index=True)

# %%
id_desicion = dating_frame[['pid','Decision','Attractive','Sincere','Intelligent','Fun','Ambitious','Shared Interests/Hobbies','like','prob']]
id_desicion
# Out:
#         pid  Decision  Attractive  Sincere  Intelligent  Fun  Ambitious  \
# 0      11.0         1         6.0      9.0          7.0  7.0        6.0
# 1      12.0         1         7.0      8.0          7.0  8.0        5.0
# 2      13.0         1         5.0      8.0          9.0  8.0        5.0
# 3      14.0         1         7.0      6.0          8.0  7.0        6.0
# 4      15.0         1         5.0      6.0          7.0  7.0        6.0
# ...     ...       ...         ...      ...          ...  ...        ...
# 8373  526.0         0         3.0      5.0          5.0  5.0        NaN
# 8374  527.0         0         4.0      6.0          8.0  4.0        4.0
# 8375  528.0         0         4.0      7.0          8.0  8.0        8.0
# 8376  529.0         0         4.0      6.0          5.0  4.0        NaN
# 8377  530.0         0         3.0      7.0          6.0  4.0        8.0
#
#       Shared Interests/Hobbies  like  prob
# 0                          5.0   7.0   6.0
# ...

# %%
group_id_desicion = id_desicion.groupby(['pid','Decision']).size().unstack(fill_value=1)
group_id_desicion.columns = ['no','yes']
group_id_desicion
# Out:
#        no  yes
# pid
# 1.0     5    5
# 2.0     4    6
# 3.0     5    5
# 4.0     4    6
# 5.0     7    3
# ...    ..  ...
# 548.0  12   10
# 549.0  12   10
# 550.0  16    6
# 551.0  12   10
# 552.0   7   15
#
# [551 rows x 2 columns]

# %%
group_id_desicion.to_excel('c:\\Users\\emlom\\OneDrive\\Documents\\3semestre\\PrograCienciasDeDatos\\ProyectoProgra\\group_id_desicion.xlsx', index=True)

# %%
id_desicion_promedio = id_desicion.columns.difference(['pid','decision'])
promedio_id = id_desicion.groupby('pid')[id_desicion_promedio].mean().reset_index()
promedio_id
# Out:
#        pid  Ambitious  Attractive  Decision       Fun  Intelligent  \
# 0      1.0   8.000000    6.700000  0.500000  7.200000     8.000000
# 1      2.0   7.500000    7.700000  0.600000  7.500000     7.900000
# 2      3.0   7.111111    6.500000  0.500000  6.200000     7.300000
# 3      4.0   7.700000    7.000000  0.600000  7.500000     7.700000
# 4      5.0   7.800000    5.300000  0.300000  7.200000     7.600000
# ..     ...        ...         ...       ...       ...          ...
# 546  548.0   6.150000    6.857143  0.454545  5.714286     6.666667
# 547  549.0   6.000000    6.350000  0.454545  6.650000     6.850000
# 548  550.0   6.363636    5.136364  0.272727  5.272727     6.500000
# 549  551.0   6.238095    6.142857  0.454545  5.571429     6.761905
# 550  552.0   6.150000    7.300000  0.681818  5.750000     6.157895
#
#      Shared Interests/Hobbies   Sincere      like      prob
# 0                    7.100000  7.400000  6.850000  5.700000
# ...

# %%
promedio_id.to_excel('c:\\Users\\emlom\\OneDrive\\Documents\\3semestre\\PrograCienciasDeDatos\\ProyectoProgra\\promedio_id.xlsx', index=True)

# %%
dating_frame_unicos = dating_frame.drop_duplicates(subset=['iid'])
dating_frame_unicos
# Out:
#       iid  gender    pid  match   age  race  imprace  imprelig  \
# 0       1       0   11.0      0  21.0   4.0      2.0       4.0
# 10      2       0   11.0      0  24.0   2.0      2.0       5.0
# 20      3       0   11.0      0  25.0   2.0      8.0       4.0
# 30      4       0   11.0      0  23.0   2.0      1.0       1.0
# 40      5       0   11.0      0  21.0   2.0      8.0       1.0
# ...   ...     ...    ...    ...   ...   ...      ...       ...
# 8268  548       1  509.0      1  30.0   2.0      8.0       8.0
# 8290  549       1  509.0      0  28.0   2.0      2.0       3.0
# 8312  550       1  509.0      0  30.0   2.0      5.0       6.0
# 8334  551       1  509.0      0  27.0   1.0      2.0       1.0
# 8356  552       1  509.0      1  25.0   2.0      1.0       1.0
#
#                    from     income  ...  Ambitious  Shared Interests/Hobbies  \
# 0               Chicago  69,487.00  ...        6.0                       5.0
# ...

# %%
dating_frame_unicos.to_excel('c:\\Users\\emlom\\OneDrive\\Documents\\3semestre\\PrograCienciasDeDatos\\ProyectoProgra\\dating_frame_unicos.xlsx', index=True)

# %%
pwd
# Out:
# 'c:\\Users\\HP\\Documents\\3er Semestre\\Progra\\PrograCienciasDeDatos\\ProyectoProgra'

# %% [markdown]
# ================ DE AQUI EN ADELANTE SE TRABAJA CON EL DATA FRAME ================

# %%
dating_real = pd.read_csv('dating_frame_unicos_proyecto.csv')
dating_real
# Out:
#      iid  gender  pid  match   age  race  imprace  imprelig  \
# 0      1       0   11      0  21.0   4.0      2.0       4.0
# 1      2       0   11      0  24.0   2.0      2.0       5.0
# 2      3       0   11      0  25.0   2.0      8.0       4.0
# 3      4       0   11      0  23.0   2.0      1.0       1.0
# 4      5       0   11      0  21.0   2.0      8.0       1.0
# ..   ...     ...  ...    ...   ...   ...      ...       ...
# 546  548       1  509      1  30.0   2.0      8.0       8.0
# 547  549       1  509      0  28.0   2.0      2.0       3.0
# 548  550       1  509      0  30.0   2.0      5.0       6.0
# 549  551       1  509      0  27.0   1.0      2.0       1.0
# 550  552       1  509      1  25.0   2.0      1.0       1.0
#
#                   from   Income  ...  yes.1  \
# 0              Chicago  69487.0  ...      5
# 1              Alabama  65929.0  ...      6
# 2          Connecticut      0.0  ...      5
# 3                Texas  37754.0  ...      6
# ...

# %%
dating_real_dataframe = pd.DataFrame(dating_real)
dating_real_dataframe
# Out:
#      iid  gender  pid  match   age  race  imprace  imprelig  \
# 0      1       0   11      0  21.0   4.0      2.0       4.0
# 1      2       0   11      0  24.0   2.0      2.0       5.0
# 2      3       0   11      0  25.0   2.0      8.0       4.0
# 3      4       0   11      0  23.0   2.0      1.0       1.0
# 4      5       0   11      0  21.0   2.0      8.0       1.0
# ..   ...     ...  ...    ...   ...   ...      ...       ...
# 546  548       1  509      1  30.0   2.0      8.0       8.0
# 547  549       1  509      0  28.0   2.0      2.0       3.0
# 548  550       1  509      0  30.0   2.0      5.0       6.0
# 549  551       1  509      0  27.0   1.0      2.0       1.0
# 550  552       1  509      1  25.0   2.0      1.0       1.0
#
#                   from   Income  ...  yes.1  \
# 0              Chicago  69487.0  ...      5
# 1              Alabama  65929.0  ...      6
# 2          Connecticut      0.0  ...      5
# 3                Texas  37754.0  ...      6
# ...

# %%
dating_real_dataframe.describe()
# Out:
#               iid      gender         pid       match         age        race  \
# count  551.000000  551.000000  551.000000  551.000000  543.000000  545.000000
# mean   276.787659    0.502722  269.693285    0.150635   26.359116    2.800000
# std    159.494486    0.500447  158.877341    0.358018    3.766960    1.253818
# min      1.000000    0.000000    1.000000    0.000000   18.000000    1.000000
# 25%    139.500000    0.000000  137.000000    0.000000   24.000000    2.000000
# 50%    277.000000    1.000000  273.000000    0.000000   26.000000    2.000000
# 75%    414.500000    1.000000  397.000000    0.000000   28.000000    4.000000
# max    552.000000    1.000000  531.000000    1.000000   55.000000    6.000000
#
#           imprace    imprelig         Income        date  ...        no.1  \
# count  544.000000  544.000000     551.000000  543.000000  ...  551.000000
# mean     3.733456    3.582721   23094.852995    4.983425  ...    8.813067
# ...

# %%
dating_real_dataframe.columns
# Out:
# Index(['iid', 'gender', 'pid', 'match', 'age', 'race', 'imprace', 'imprelig',
#        'from', 'Income', 'date', 'go_out', 'career', 'sports', 'tvsports',
#        'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming', 'clubbing',
#        'reading', 'tv', 'theater', 'movies', 'concerts', 'music', 'shopping',
#        'yoga', 'QUE BUSCA ', 'Attractive1', 'Sincere1', 'Intelligent1', 'Fun1',
#        'Ambitious1', 'Has shared interests/hobbies1', 'QUE PIENSA DE SI MISMO',
#        'attr3_2', 'sinc3_2', 'intel3_2', 'fun3_2', 'amb3_2',
#        'Matches no/si efectivos', 'no', 'yes', 'Si saldrian con ellos otravez',
#        'no.1', 'yes.1', 'Rating que obtuvieron de sus dates', 'Ambitious',
#        'Attractive', 'Fun', 'Intelligent', 'Shared Interests/Hobbies',
#        'Sincere', 'like', 'prob'],
#       dtype='object')

# %%
mujeres = (dating_real_dataframe['gender'] == 0)

# %%
hombres = (dating_real_dataframe['gender'] == 1)

# %%
personas_guapas = (dating_real_dataframe['Attractive'] >= 8)

# %%
personas_inteligentes = (dating_real_dataframe['Intelligent'] >= 8)

# %%
personas_con_altas_probabilidades = (dating_real_dataframe['prob'] >= 7)

# %%
dating_real_dataframe[hombres].loc[:,'sports':'yoga']
# Out:
#      sports  tvsports  exercise  dining  museums   art  hiking  gaming  \
# 10      8.0       7.0       2.0     6.0      7.0   5.0     5.0     5.0
# 11      9.0       7.0       9.0     8.0      7.0   6.0     3.0     3.0
# 12      7.0       8.0       2.0     9.0      5.0   6.0     4.0     7.0
# 13     10.0       6.0       8.0     8.0      3.0   3.0    10.0     8.0
# 14      9.0       7.0       9.0     7.0      4.0   3.0     6.0     7.0
# ..      ...       ...       ...     ...      ...   ...     ...     ...
# 546    10.0       8.0       4.0    10.0      3.0   2.0     2.0     5.0
# 547     8.0       5.0       6.0     9.0      7.0   7.0     4.0     8.0
# 548     5.0       3.0       5.0     9.0      7.0   8.0     3.0     3.0
# 549     6.0       1.0       7.0     6.0      7.0   3.0     2.0     1.0
# 550     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
#
#      clubbing  reading   tv  theater  movies  concerts  music  shopping  yoga
# ...

# %%
dating_real_dataframe[mujeres].loc[:,'sports':'yoga']
# Out:
#      sports  tvsports  exercise  dining  museums  art  hiking  gaming  \
# 0       9.0       2.0       8.0     9.0      1.0  1.0     5.0     1.0
# 1       3.0       2.0       7.0    10.0      8.0  6.0     3.0     5.0
# 2       3.0       8.0       7.0     8.0      5.0  5.0     8.0     4.0
# 3       1.0       1.0       6.0     7.0      6.0  7.0     7.0     5.0
# 4       7.0       4.0       7.0     7.0      6.0  8.0     6.0     6.0
# ..      ...       ...       ...     ...      ...  ...     ...     ...
# 524     2.0       1.0       3.0    10.0     10.0  7.0     6.0     5.0
# 525     5.0       5.0       1.0     8.0      7.0  7.0     6.0     2.0
# 526     5.0       8.0       4.0     2.0      2.0  2.0     8.0     6.0
# 527     7.0       4.0       6.0    10.0      8.0  8.0     8.0     6.0
# 528     7.0      10.0       5.0     6.0      3.0  8.0     6.0     7.0
#
#      clubbing  reading   tv  theater  movies  concerts  music  shopping  yoga
# ...

# %%
mujeres_inteligentes_guapas = (mujeres & personas_inteligentes & personas_guapas)
dating_real_dataframe[mujeres_inteligentes_guapas]
# Out:
#      iid  gender  pid  match   age  race  imprace  imprelig             from  \
# 7      8       0   11      0  25.0   2.0      1.0       1.0  London, England
# 90    91       0   94      0  25.0   6.0      6.0       8.0       California
# 177  179       0  184      0  30.0   3.0      5.0       1.0       California
# 266  268       0  273      1  24.0   3.0      1.0       1.0            Texas
# 466  468       0  481      0  25.0   6.0      5.0       2.0  Detroit suburbs
# 468  470       0  481      0  29.0   4.0      1.0       1.0   south carolina
# 476  478       0  481      0  26.0   2.0      4.0       4.0    Washington DC
#
#       Income  ...  yes.1  Rating que obtuvieron de sus dates Ambitious  \
# 7        0.0  ...      8  Rating que obtuvieron de sus dates  7.444444
# 90   40409.0  ...     16  Rating que obtuvieron de sus dates  8.187500
# 177  78704.0  ...      8  Rating que obtuvieron de sus dates  7.777778
# ...

# %%
dating_real_dataframe[mujeres_inteligentes_guapas].describe()
# Out:
#               iid  gender         pid     match        age      race  \
# count    7.000000     7.0    7.000000  7.000000   7.000000  7.000000
# mean   280.285714     0.0  286.428571  0.142857  26.285714  3.714286
# std    196.085623     0.0  198.802965  0.377964   2.288689  1.704336
# min      8.000000     0.0   11.000000  0.000000  24.000000  2.000000
# 25%    135.000000     0.0  139.000000  0.000000  25.000000  2.500000
# 50%    268.000000     0.0  273.000000  0.000000  25.000000  3.000000
# 75%    469.000000     0.0  481.000000  0.000000  27.500000  5.000000
# max    478.000000     0.0  481.000000  1.000000  30.000000  6.000000
#
#         imprace  imprelig        Income      date  ...      no.1      yes.1  \
# count  7.000000  7.000000      7.000000  7.000000  ...  7.000000   7.000000
# mean   3.285714  2.571429  36345.000000  4.857143  ...  2.857143  12.000000
# std    2.214670  2.636737  35907.826092  1.214986  ...  1.463850   4.434712
# ...

# %%
#holaaa putito

# %%
#Primera pregunta 
# 1.Que genero es mas rechazado, por que ?
# Calcular la tasa de rechazo para cada género
rechazo_mujeres = dating_real_dataframe[mujeres]['match'].value_counts(normalize=True)[0]
rechazo_hombres = dating_real_dataframe[hombres]['match'].value_counts(normalize=True)[0]

rechazo_mujeres, rechazo_hombres
#Tasa de rechazo para mujeres: 88.32% 
#Tasa de rechazo para hombres: 81.59%
# Out:
# (0.8832116788321168, 0.8158844765342961)

# %%
# Que caracteristicas tienen en comun los usuarios rechazados
# Características de las mujeres rechazadas
caracteristicas_mujeres_rechazadas = dating_real_dataframe[mujeres & (dating_real_dataframe['match'] == 0)][['age','gender','attr3_2','intel3_2','Fun','amb3_2']].mode() 
salario_mujeres_rechazadas = dating_real_dataframe[mujeres & (dating_real_dataframe['match'] == 0)]['Income'].mean() 


# Características de los hombres rechazados
caracteristicas_hombres_rechazados = dating_real_dataframe[hombres & (dating_real_dataframe['match'] == 0)][['age','career','attr3_2','intel3_2','Fun','amb3_2']].mode()
salario_hombres_rechazados = dating_real_dataframe[hombres & (dating_real_dataframe['match'] == 0)]['Income'].mean()


caracteristicas_mujeres_rechazadas.iloc[0],salario_mujeres_rechazadas, caracteristicas_hombres_rechazados.iloc[0],salario_hombres_rechazados
# Out:
# (age         23.0
#  gender       0.0
#  attr3_2      7.0
#  intel3_2     8.0
#  Fun          7.2
#  amb3_2       7.0
#  Name: 0, dtype: float64,
#  26559.15702479339,
#  age            27.0
#  career      Finance
#  attr3_2         7.0
#  intel3_2        8.0
#  Fun             7.0
#  amb3_2          8.0
#  Name: 0, dtype: object,
#  20458.194690265485)

# %%
# 1.Que genero es mas aceptado, por que ?
# Calcular la tasa de rechazo para cada género
aceptacion_mujeres = dating_real_dataframe[mujeres]['match'].value_counts(normalize=True)[1]
aceptacion_hombres = dating_real_dataframe[hombres]['match'].value_counts(normalize=True)[1]

aceptacion_mujeres, aceptacion_hombres
#Tasa de rechazo para mujeres: 11.67% 
#Tasa de rechazo para hombres: 18.41%
# Out:
# (0.11678832116788321, 0.18411552346570398)

# %%
# Que caracteristicas tienen en comun los usuarios rechazados
# Características de las mujeres rechazadas
caracteristicas_mujeres_aceptadas = dating_real_dataframe[mujeres & (dating_real_dataframe['match'] == 1)][['age','gender','attr3_2','intel3_2','Fun','amb3_2']].mode() 
salario_mujeres_aceptadas = dating_real_dataframe[mujeres & (dating_real_dataframe['match'] == 1)]['Income'].mean() 


# Características de los hombres rechazados
caracteristicas_hombres_aceptados = dating_real_dataframe[hombres & (dating_real_dataframe['match'] == 1)][['age','career','attr3_2','intel3_2','Fun','amb3_2']].mode()
salario_hombres_aceptados = dating_real_dataframe[hombres & (dating_real_dataframe['match'] == 1)]['Income'].mean()


caracteristicas_mujeres_aceptadas.iloc[0],salario_mujeres_aceptadas, caracteristicas_hombres_aceptados.iloc[0],salario_hombres_aceptados
# Out:
# (age         29.0
#  gender       0.0
#  attr3_2      7.0
#  intel3_2     8.0
#  Fun          6.2
#  amb3_2       8.0
#  Name: 0, dtype: float64,
#  24168.03125,
#  age                       27.0
#  career      Investment Banking
#  attr3_2                    8.0
#  intel3_2                   9.0
#  Fun                   5.833333
#  amb3_2                     8.0
#  Name: 0, dtype: object,
#  17667.039215686276)

# %%
import matplotlib.pyplot as plt


# Calcular la tasa de "likes" para cada edad
likes_por_edad = dating_real_dataframe.groupby('age')['match'].mean()

# Visualizar los resultados
plt.figure(figsize=(10, 6))
plt.plot(likes_por_edad.index, likes_por_edad.values, marker='o')
plt.xlabel('Edad')
plt.ylabel('Probabilidad de recibir un "like"')
plt.title('Probabilidad de recibir un "like" según la edad')
plt.grid(True)
plt.show()

# Encontrar la edad con la mayor tasa de "likes"
edad_optima = likes_por_edad.idxmax()
tasa_maxima_likes = likes_por_edad.max()

print(f"La edad óptima para recibir más 'likes' es {edad_optima} con una tasa de 'likes' de {tasa_maxima_likes:.2f}")
# Out:
# La edad óptima para recibir más 'likes' es 20.0 con una tasa de 'likes' de 0.40
